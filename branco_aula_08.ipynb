# %%
# !pip install langchain==0.3.0
# !pip install langchain-groq==0.2.0
# !pip install langchain-community==0.3.0
# !pip install youtube_transcript_api==0.6.2
# !pip install pypdf==5.0.1
# Out:
# Requirement already satisfied: youtube_transcript_api==0.6.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.6.2)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from youtube_transcript_api==0.6.2) (2.32.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->youtube_transcript_api==0.6.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->youtube_transcript_api==0.6.2) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->youtube_transcript_api==0.6.2) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->youtube_transcript_api==0.6.2) (2024.2.2)
# WARNING: Error parsing dependencies of console: Invalid version: 'Darwin Kernel Version 23.6.0: Mon Jul 29 21:14:30 PDT 2024; root:xnu-10063.141.2~1/RELEASE_ARM64_T6000'
# Requirement already satisfied: pypdf==5.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (5.0.1)
# WARNING: Error parsing dependencies of console: Invalid version: 'Darwin Kernel Version 23.6.0: Mon Jul 29 21:14:30 PDT 2024; root:xnu-10063.141.2~1/RELEASE_ARM64_T6000'

# %% [markdown]
# # Aula 8: Acessando vídeos de Youtube e PDFs

# %%
from dotenv import load_dotenv, find_dotenv
from langchain_groq import ChatGroq
from langchain.prompts import ChatPromptTemplate

_ = load_dotenv(find_dotenv())

chat = ChatGroq(model='llama-3.1-70b-versatile')

# %% [markdown]
# ## Acessando o Youtube

# %% [markdown]
# E agora vamos mostrar o quão fácil é de acessar vídeos de youtube utilizando LangChain!

# %%
from langchain_community.document_loaders import YoutubeLoader

url = 'https://www.youtube.com/watch?v=1gOMpczyTpI&t=4s'

loader_yt = YoutubeLoader.from_youtube_url(
    url,
    language=['pt']
)

lista_documentos_yt = loader_yt.load()

# %%
documento_yt = ''
for doc in lista_documentos_yt:
    documento_yt += doc.page_content

# %%
template = ChatPromptTemplate.from_messages([
    ('system', 'Você é um assistente amigável que possui as seguintes informações para formular uma resposta: {informacoes}'),
    ('user', '{input}')
])

chain_youtube = template | chat

resposta_yt = chain_youtube.invoke({'informacoes': documento_yt, 'input': 'Qual o título do vídeo e qual seu tema central?'})

print(resposta_yt.content)
# Out:
# Desculpe, mas não tenho informações suficientes para fornecer uma resposta precisa. Você poderia fornecer mais contexto ou detalhes sobre o vídeo que você está se referindo? Isso me ajudaria a fornecer uma resposta mais precisa.

# %% [markdown]
# ## Acessando PDFs

# %%
from langchain_community.document_loaders import PyPDFLoader

caminho = 'arquivos/2024-07-15_Discussion_Paper_Hamburg_DPA_KI_Models.pdf'

loader_pdf = PyPDFLoader(caminho)

lista_documentos_pdf = loader_pdf.load()

# %%
documento_pdf = ''

for doc in lista_documentos_pdf:
    documento_pdf += doc.page_content

# %%
template = ChatPromptTemplate.from_messages([
    ('system', 'Você é um assistente amigável que possui as seguintes informações para formular uma resposta: {informacoes}'),
    ('user', '{input}')
])

chain_pdf = template | chat

resposta_pdf = chain_pdf.invoke({'informacoes': documento_pdf, 'input': 'Quais as principais conclusões do documento?'})

print(resposta_pdf.content)
# Out:
# O documento apresenta as seguintes principais conclusões:
#
# 1. **Armazenamento de dados pessoais em LLMs**: O documento conclui que os LLMs (Large Language Models) não armazenam dados pessoais no sentido da GDPR (Regulamento Geral de Proteção de Dados). Isso ocorre porque os LLMs processam linguagem e não armazenam informações pessoais em sua forma original.
#
# 2. **Direitos dos titulares de dados**: Embora os LLMs não armazenem dados pessoais, os titulares de dados ainda podem exercer seus direitos em relação ao input e output do sistema de IA que utiliza o LLM.
#
# 3. **Treinamento de LLMs com dados pessoais**: O treinamento de LLMs com dados pessoais deve ser feito em conformidade com as regulamentações de proteção de dados. No entanto, violações durante o treinamento não afetam a legalidade do uso do modelo.
#
# 4. **Implicações práticas**: O documento apresenta implicações práticas para a implementação de LLMs em diferentes cenários, incluindo a necessidade de garantir a conformidade com a GDPR, a importância de proteger contra ataques de privacidade e a necessidade de esclarecer as responsabilidades em caso de uso de LLMs terceirizados.
#
# Essas conclusões têm implicações importantes para a implementação de LLMs em diferentes contextos, incluindo a proteção de dados pessoais e a conformidade com regulamentações de proteção de dados.
