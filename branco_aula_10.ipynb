# %%
# !pip install langchain==0.3.0
# !pip install langchain-groq==0.2.0
# !pip install langchain-community==0.3.0
# !pip install youtube_transcript_api==0.6.2
# !pip install pypdf==5.0.1
# Out:
# Requirement already satisfied: langchain==0.3.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (0.3.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain==0.3.0) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain==0.3.0) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain==0.3.0) (3.10.10)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain==0.3.0) (0.3.13)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain==0.3.0) (0.3.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain==0.3.0) (0.1.137)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain==0.3.0) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain==0.3.0) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain==0.3.0) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain==0.3.0) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (1.16.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain==0.3.0) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\mpass\appdata\roaming\python\python313\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain==0.3.0) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain==0.3.0) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (3.10.10)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.0) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langchain==0.3.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langchain==0.3.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langchain==0.3.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langchain==0.3.0) (2024.8.30)
# Requirement already satisfied: anyio in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (1.0.6)
# Requirement already satisfied: sniffio in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.0->langchain==0.3.0) (3.0.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (0.2.0)
# Requirement already satisfied: langchain-groq==0.2.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (0.2.0)
# Requirement already satisfied: groq<1,>=0.4.1 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain-groq==0.2.0) (0.11.0)
# Requirement already satisfied: langchain-core<0.4,>=0.3 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain-groq==0.2.0) (0.3.13)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from groq<1,>=0.4.1->langchain-groq==0.2.0) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from groq<1,>=0.4.1->langchain-groq==0.2.0) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from groq<1,>=0.4.1->langchain-groq==0.2.0) (0.27.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from groq<1,>=0.4.1->langchain-groq==0.2.0) (2.9.2)
# Requirement already satisfied: sniffio in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from groq<1,>=0.4.1->langchain-groq==0.2.0) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from groq<1,>=0.4.1->langchain-groq==0.2.0) (4.12.2)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (0.1.137)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\mpass\appdata\roaming\python\python313\site-packages (from langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (24.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (8.5.0)
# Requirement already satisfied: idna>=2.8 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq==0.2.0) (3.10)
# Requirement already satisfied: certifi in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq==0.2.0) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq==0.2.0) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq==0.2.0) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (3.10.10)
# Requirement already satisfied: requests<3,>=2 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq==0.2.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq==0.2.0) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (2.2.3)
# Requirement already satisfied: langchain-community==0.3.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (0.3.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain-community==0.3.0) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain-community==0.3.0) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain-community==0.3.0) (3.10.10)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain-community==0.3.0) (0.6.7)
# Requirement already satisfied: langchain<0.4.0,>=0.3.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain-community==0.3.0) (0.3.0)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain-community==0.3.0) (0.3.13)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.112 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain-community==0.3.0) (0.1.137)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain-community==0.3.0) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain-community==0.3.0) (2.6.0)
# Requirement already satisfied: requests<3,>=2 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain-community==0.3.0) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain-community==0.3.0) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.0) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.0) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.0) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.0) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.0) (1.16.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.0) (3.23.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.0) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain<0.4.0,>=0.3.0->langchain-community==0.3.0) (0.3.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain<0.4.0,>=0.3.0->langchain-community==0.3.0) (2.9.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-community==0.3.0) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\mpass\appdata\roaming\python\python313\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-community==0.3.0) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-community==0.3.0) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-community==0.3.0) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-community==0.3.0) (3.10.10)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-community==0.3.0) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community==0.3.0) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langchain-community==0.3.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langchain-community==0.3.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langchain-community==0.3.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langchain-community==0.3.0) (2024.8.30)
# Requirement already satisfied: anyio in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community==0.3.0) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community==0.3.0) (1.0.6)
# Requirement already satisfied: sniffio in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community==0.3.0) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community==0.3.0) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.0->langchain-community==0.3.0) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.0->langchain-community==0.3.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.0->langchain-community==0.3.0) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.0) (1.0.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.0) (0.2.0)
# Requirement already satisfied: youtube_transcript_api==0.6.2 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (0.6.2)
# Requirement already satisfied: requests in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from youtube_transcript_api==0.6.2) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from requests->youtube_transcript_api==0.6.2) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from requests->youtube_transcript_api==0.6.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from requests->youtube_transcript_api==0.6.2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from requests->youtube_transcript_api==0.6.2) (2024.8.30)
# Requirement already satisfied: pypdf==5.0.1 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (5.0.1)

# %% [markdown]
# # Aula 10: Finalizando o projeto

# %% [markdown]
# E agora é só chutar para o gol!
#
# **Comece copiando o código desenvolvido na aula 9!**

# %%
from dotenv import load_dotenv, find_dotenv
from langchain_groq import ChatGroq
from langchain.prompts import ChatPromptTemplate
from langchain_community.document_loaders import WebBaseLoader, YoutubeLoader, PyPDFLoader

_ = load_dotenv(find_dotenv())

chat = ChatGroq(model='llama-3.1-70b-versatile')

def resposta_bot(mensagens, documento):
    system_message = 'Você é um modelo amigável chamado Asimo. Você utiliza as seguintes informações para formular as suas respostas: {informacoes}'
    mensagens_modelo = [('system', system_message)]
    mensagens_modelo += mensagens
    template = ChatPromptTemplate.from_messages(mensagens_modelo)
    chain = template | chat
    return chain.invoke({'informacoes': documento}).content





def carrega_site():
    url_site = input('Digite a URL do site: ')
    loader = WebBaseLoader(url_site) # O loader do LangChain sempre retorna uma lista
    lista_documentos = loader.load()
    documento = ''
    for doc in lista_documentos:
        documento += doc.page_content
    return documento

def carrega_PDF():
    caminho = 'arquivos/2024-07-15_Discussion_Paper_Hamburg_DPA_KI_Models.pdf'
    loader = PyPDFLoader(caminho)
    lista_documentos = loader.load()
    documento = ''
    for doc in lista_documentos:
        documento += doc.page_content
    return documento

def carrega_YT():
    url_site = input('Digite a URL do vídeo do YouTube: ')
    loader = YoutubeLoader.from_youtube_url(url_site, language=['pt'])
    lista_documentos = loader.load()
    documento = ''
    for doc in lista_documentos:
        documento += doc.page_content
    return documento

print('Bem-vindo ao ChatBot da Asimo! (Digite x se você quiser sair!)\n')

texto_selecao = '''
Digite 1 se você quiser conversar com um site
Digite 2 se você quiser conversar com um PDF
Digite 3 se você quiser conversar com um vídeo do YouTube
'''

while True:
  selecao = input(texto_selecao)
  if selecao == '1':
    documento = carrega_site()
    break
  if selecao == '2':
    documento = carrega_PDF()
    break
  if selecao == '3':
    documento = carrega_YT()
    break
  print('Digite apenas um valor entre 1 e 3!')



mensagens = []
while True:
  pergunta = input('Usuário: ')
  if pergunta.lower() == 'x':
    break
  mensagens.append(('user', pergunta))
  resposta = resposta_bot(mensagens, documento)
  mensagens.append(('assistant', resposta))
  print(f'Bot: {resposta}')

print('\nMuito obrigado por utilizar o AsimoBot!')
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# Bem-vindo ao ChatBot da Asimo! (Digite x se você quiser sair!)
# ---------------------------------------------------------------------------
# APIStatusError                            Traceback (most recent call last)
# Cell In[2], line 78
#      76   break
#      77 mensagens.append(('user', pergunta))
# ---> 78 resposta = resposta_bot(mensagens, documento)
#      79 mensagens.append(('assistant', resposta))
#      80 print(f'Bot: {resposta}')
#
# Cell In[2], line 16, in resposta_bot(mensagens, documento)
#      14 template = ChatPromptTemplate.from_messages(mensagens_modelo)
#      15 chain = template | chat
# ---> 16 return chain.invoke({'informacoes': documento}).content
#
# File c:\Users\mpass\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\runnables\base.py:3024, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3022             input = context.run(step.invoke, input, config, **kwargs)
#    3023         else:
# -> 3024             input = context.run(step.invoke, input, config)
#    3025 # finish the root run
#    3026 except BaseException as e:
#
# File c:\Users\mpass\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:286, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     275 def invoke(
#     276     self,
#     277     input: LanguageModelInput,
#    (...)
#     281     **kwargs: Any,
#     282 ) -> BaseMessage:
#     283     config = ensure_config(config)
#     284     return cast(
#     285         ChatGeneration,
# --> 286         self.generate_prompt(
#     287             [self._convert_input(input)],
#     288             stop=stop,
#     289             callbacks=config.get("callbacks"),
#     290             tags=config.get("tags"),
#     291             metadata=config.get("metadata"),
#     292             run_name=config.get("run_name"),
#     293             run_id=config.pop("run_id", None),
#     294             **kwargs,
#     295         ).generations[0][0],
#     296     ).message
#
# File c:\Users\mpass\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:786, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     778 def generate_prompt(
#     779     self,
#     780     prompts: list[PromptValue],
#    (...)
#     783     **kwargs: Any,
#     784 ) -> LLMResult:
#     785     prompt_messages = [p.to_messages() for p in prompts]
# --> 786     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\mpass\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:643, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     641         if run_managers:
#     642             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 643         raise e
#     644 flattened_outputs = [
#     645     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     646     for res in results
#     647 ]
#     648 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File c:\Users\mpass\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:633, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     630 for i, m in enumerate(messages):
#     631     try:
#     632         results.append(
# --> 633             self._generate_with_cache(
#     634                 m,
#     635                 stop=stop,
#     636                 run_manager=run_managers[i] if run_managers else None,
#     637                 **kwargs,
#     638             )
#     639         )
#     640     except BaseException as e:
#     641         if run_managers:
#
# File c:\Users\mpass\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:851, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     849 else:
#     850     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 851         result = self._generate(
#     852             messages, stop=stop, run_manager=run_manager, **kwargs
#     853         )
#     854     else:
#     855         result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\mpass\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_groq\chat_models.py:473, in ChatGroq._generate(self, messages, stop, run_manager, **kwargs)
#     468 message_dicts, params = self._create_message_dicts(messages, stop)
#     469 params = {
#     470     **params,
#     471     **kwargs,
#     472 }
# --> 473 response = self.client.create(messages=message_dicts, **params)
#     474 return self._create_chat_result(response)
#
# File c:\Users\mpass\AppData\Local\Programs\Python\Python313\Lib\site-packages\groq\resources\chat\completions.py:287, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     146 def create(
#     147     self,
#     148     *,
#    (...)
#     175     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     176 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     177     """
#     178     Creates a model response for the given chat conversation.
#     179
#    (...)
#     285       timeout: Override the client-level default timeout for this request, in seconds
#     286     """
# --> 287     return self._post(
#     288         "/openai/v1/chat/completions",
#     289         body=maybe_transform(
#     290             {
#     291                 "messages": messages,
#     292                 "model": model,
#     293                 "frequency_penalty": frequency_penalty,
#     294                 "function_call": function_call,
#     295                 "functions": functions,
#     296                 "logit_bias": logit_bias,
#     297                 "logprobs": logprobs,
#     298                 "max_tokens": max_tokens,
#     299                 "n": n,
#     300                 "parallel_tool_calls": parallel_tool_calls,
#     301                 "presence_penalty": presence_penalty,
#     302                 "response_format": response_format,
#     303                 "seed": seed,
#     304                 "stop": stop,
#     305                 "stream": stream,
#     306                 "temperature": temperature,
#     307                 "tool_choice": tool_choice,
#     308                 "tools": tools,
#     309                 "top_logprobs": top_logprobs,
#     310                 "top_p": top_p,
#     311                 "user": user,
#     312             },
#     313             completion_create_params.CompletionCreateParams,
#     314         ),
#     315         options=make_request_options(
#     316             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     317         ),
#     318         cast_to=ChatCompletion,
#     319         stream=stream or False,
#     320         stream_cls=Stream[ChatCompletionChunk],
#     321     )
#
# File c:\Users\mpass\AppData\Local\Programs\Python\Python313\Lib\site-packages\groq\_base_client.py:1244, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1230 def post(
#    1231     self,
#    1232     path: str,
#    (...)
#    1239     stream_cls: type[_StreamT] | None = None,
#    1240 ) -> ResponseT | _StreamT:
#    1241     opts = FinalRequestOptions.construct(
#    1242         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1243     )
# -> 1244     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\mpass\AppData\Local\Programs\Python\Python313\Lib\site-packages\groq\_base_client.py:936, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     927 def request(
#     928     self,
#     929     cast_to: Type[ResponseT],
#    (...)
#     934     stream_cls: type[_StreamT] | None = None,
#     935 ) -> ResponseT | _StreamT:
# --> 936     return self._request(
#     937         cast_to=cast_to,
#     938         options=options,
#     939         stream=stream,
#     940         stream_cls=stream_cls,
#     941         remaining_retries=remaining_retries,
#     942     )
#
# File c:\Users\mpass\AppData\Local\Programs\Python\Python313\Lib\site-packages\groq\_base_client.py:1039, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1036         err.response.read()
#    1038     log.debug("Re-raising status error")
# -> 1039     raise self._make_status_error_from_response(err.response) from None
#    1041 return self._process_response(
#    1042     cast_to=cast_to,
#    1043     options=options,
#    (...)
#    1047     retries_taken=options.get_max_retries(self.max_retries) - retries,
#    1048 )
#
# APIStatusError: Error code: 413 - {'error': {'message': 'Request too large for model `llama-3.1-70b-versatile` in organization `org_01j12724tefwwa6vnadvzstvs9` on tokens per minute (TPM): Limit 6000, Requested 7564, please reduce your message size and try again. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
