# %%
# !pip install langchain==0.3.0
# !pip install langchain-groq==0.2.0
# !pip install langchain-community==0.3.0
# !pip install youtube_transcript_api==0.6.2
# !pip install pypdf==5.0.1
# Out:
# Collecting langchain==0.3.0
#   Downloading langchain-0.3.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting PyYAML>=5.3 (from langchain==0.3.0)
#   Downloading PyYAML-6.0.2-cp313-cp313-win_amd64.whl.metadata (2.1 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain==0.3.0)
#   Downloading SQLAlchemy-2.0.36-cp313-cp313-win_amd64.whl.metadata (9.9 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain==0.3.0)
#   Downloading aiohttp-3.10.10-cp313-cp313-win_amd64.whl.metadata (7.8 kB)
# Collecting langchain-core<0.4.0,>=0.3.0 (from langchain==0.3.0)
#   Downloading langchain_core-0.3.13-py3-none-any.whl.metadata (6.3 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.0 (from langchain==0.3.0)
#   Downloading langchain_text_splitters-0.3.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain==0.3.0)
#   Downloading langsmith-0.1.137-py3-none-any.whl.metadata (13 kB)
# Collecting numpy<2.0.0,>=1.26.0 (from langchain==0.3.0)
#   Downloading numpy-1.26.4.tar.gz (15.8 MB)
#      ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#      -------- ------------------------------- 3.4/15.8 MB 18.7 MB/s eta 0:00:01
#      ----------------- ---------------------- 7.1/15.8 MB 17.5 MB/s eta 0:00:01
#      -------------------------- ------------ 10.7/15.8 MB 17.7 MB/s eta 0:00:01
#      ------------------------------------ -- 14.7/15.8 MB 18.2 MB/s eta 0:00:01
#      --------------------------------------- 15.8/15.8 MB 17.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [21 lines of output]
#       + C:\Users\mpass\AppData\Local\Programs\Python\Python313\python.exe C:\Users\mpass\AppData\Local\Temp\pip-install-putvx1cm\numpy_7683f1dc20834f1b81dc3c864b98c1d0\vendored-meson\meson\meson.py setup C:\Users\mpass\AppData\Local\Temp\pip-install-putvx1cm\numpy_7683f1dc20834f1b81dc3c864b98c1d0 C:\Users\mpass\AppData\Local\Temp\pip-install-putvx1cm\numpy_7683f1dc20834f1b81dc3c864b98c1d0\.mesonpy-3efgtp6a -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=C:\Users\mpass\AppData\Local\Temp\pip-install-putvx1cm\numpy_7683f1dc20834f1b81dc3c864b98c1d0\.mesonpy-3efgtp6a\meson-python-native-file.ini
#       The Meson build system
#       Version: 1.2.99
#       Source dir: C:\Users\mpass\AppData\Local\Temp\pip-install-putvx1cm\numpy_7683f1dc20834f1b81dc3c864b98c1d0
#       Build dir: C:\Users\mpass\AppData\Local\Temp\pip-install-putvx1cm\numpy_7683f1dc20834f1b81dc3c864b98c1d0\.mesonpy-3efgtp6a
#       Build type: native build
#       Project name: NumPy
#       Project version: 1.26.4
#       WARNING: Failed to activate VS environment: Could not find C:\Program Files (x86)\Microsoft Visual Studio\Installer\vswhere.exe
#
#       ..\meson.build:1:0: ERROR: Unknown compiler(s): [['icl'], ['cl'], ['cc'], ['gcc'], ['clang'], ['clang-cl'], ['pgcc']]
#       The following exception(s) were encountered:
#       Running `icl ""` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#       Running `cl /?` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#       Running `cc --version` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#       Running `gcc --version` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#       Running `clang --version` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#       Running `clang-cl /?` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#       Running `pgcc --version` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#
#       A full log can be found at C:\Users\mpass\AppData\Local\Temp\pip-install-putvx1cm\numpy_7683f1dc20834f1b81dc3c864b98c1d0\.mesonpy-3efgtp6a\meson-logs\meson-log.txt
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 24.2 -> 24.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Collecting langchain-groq==0.2.0
# [notice] A new release of pip is available: 24.2 -> 24.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Downloading langchain_groq-0.2.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting groq<1,>=0.4.1 (from langchain-groq==0.2.0)
#   Downloading groq-0.11.0-py3-none-any.whl.metadata (13 kB)
# Collecting langchain-core<0.4,>=0.3 (from langchain-groq==0.2.0)
#   Using cached langchain_core-0.3.13-py3-none-any.whl.metadata (6.3 kB)
# Collecting anyio<5,>=3.5.0 (from groq<1,>=0.4.1->langchain-groq==0.2.0)
#   Downloading anyio-4.6.2.post1-py3-none-any.whl.metadata (4.7 kB)
# Collecting distro<2,>=1.7.0 (from groq<1,>=0.4.1->langchain-groq==0.2.0)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from groq<1,>=0.4.1->langchain-groq==0.2.0)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting pydantic<3,>=1.9.0 (from groq<1,>=0.4.1->langchain-groq==0.2.0)
#   Downloading pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
# Collecting sniffio (from groq<1,>=0.4.1->langchain-groq==0.2.0)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting typing-extensions<5,>=4.7 (from groq<1,>=0.4.1->langchain-groq==0.2.0)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting PyYAML>=5.3 (from langchain-core<0.4,>=0.3->langchain-groq==0.2.0)
#   Using cached PyYAML-6.0.2-cp313-cp313-win_amd64.whl.metadata (2.1 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.4,>=0.3->langchain-groq==0.2.0)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<0.2.0,>=0.1.125 (from langchain-core<0.4,>=0.3->langchain-groq==0.2.0)
#   Using cached langsmith-0.1.137-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\mpass\appdata\roaming\python\python313\site-packages (from langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (24.1)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<0.4,>=0.3->langchain-groq==0.2.0)
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq==0.2.0)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting certifi (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq==0.2.0)
#   Downloading certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq==0.2.0)
#   Downloading httpcore-1.0.6-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq==0.2.0)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3->langchain-groq==0.2.0)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-groq==0.2.0)
#   Downloading orjson-3.10.10-cp313-none-win_amd64.whl.metadata (51 kB)
# Collecting requests<3,>=2 (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-groq==0.2.0)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-groq==0.2.0)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq==0.2.0)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.23.4 (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq==0.2.0)
#   Downloading pydantic_core-2.23.4-cp313-none-win_amd64.whl.metadata (6.7 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-groq==0.2.0)
#   Downloading charset_normalizer-3.4.0-cp313-cp313-win_amd64.whl.metadata (34 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-groq==0.2.0)
#   Downloading urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Downloading langchain_groq-0.2.0-py3-none-any.whl (14 kB)
# Downloading groq-0.11.0-py3-none-any.whl (106 kB)
# Downloading langchain_core-0.3.13-py3-none-any.whl (408 kB)
# Downloading anyio-4.6.2.post1-py3-none-any.whl (90 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
# Downloading httpcore-1.0.6-py3-none-any.whl (78 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langsmith-0.1.137-py3-none-any.whl (296 kB)
# Downloading pydantic-2.9.2-py3-none-any.whl (434 kB)
# Downloading pydantic_core-2.23.4-cp313-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 1.9/1.9 MB 14.0 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp313-cp313-win_amd64.whl (156 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading orjson-3.10.10-cp313-none-win_amd64.whl (139 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading charset_normalizer-3.4.0-cp313-cp313-win_amd64.whl (102 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
# Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
# Installing collected packages: urllib3, typing-extensions, tenacity, sniffio, PyYAML, orjson, jsonpointer, idna, h11, distro, charset-normalizer, certifi, annotated-types, requests, pydantic-core, jsonpatch, httpcore, anyio, requests-toolbelt, pydantic, httpx, langsmith, groq, langchain-core, langchain-groq
# Successfully installed PyYAML-6.0.2 annotated-types-0.7.0 anyio-4.6.2.post1 certifi-2024.8.30 charset-normalizer-3.4.0 distro-1.9.0 groq-0.11.0 h11-0.14.0 httpcore-1.0.6 httpx-0.27.2 idna-3.10 jsonpatch-1.33 jsonpointer-3.0.0 langchain-core-0.3.13 langchain-groq-0.2.0 langsmith-0.1.137 orjson-3.10.10 pydantic-2.9.2 pydantic-core-2.23.4 requests-2.32.3 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.0.0 typing-extensions-4.12.2 urllib3-2.2.3
# Collecting langchain-community==0.3.0
#   Downloading langchain_community-0.3.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain-community==0.3.0) (6.0.2)
# Collecting SQLAlchemy<3,>=1.4 (from langchain-community==0.3.0)
#   Using cached SQLAlchemy-2.0.36-cp313-cp313-win_amd64.whl.metadata (9.9 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community==0.3.0)
#   Using cached aiohttp-3.10.10-cp313-cp313-win_amd64.whl.metadata (7.8 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community==0.3.0)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting langchain<0.4.0,>=0.3.0 (from langchain-community==0.3.0)
#   Downloading langchain-0.3.4-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.0 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain-community==0.3.0) (0.3.13)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.112 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from langchain-community==0.3.0) (0.1.137)
# Collecting numpy<2.0.0,>=1.26.0 (from langchain-community==0.3.0)
#   Using cached numpy-1.26.4.tar.gz (15.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [21 lines of output]
#       + C:\Users\mpass\AppData\Local\Programs\Python\Python313\python.exe C:\Users\mpass\AppData\Local\Temp\pip-install-dgy9025w\numpy_2d8430dde7ef49e8aae9b794b2ceeb4d\vendored-meson\meson\meson.py setup C:\Users\mpass\AppData\Local\Temp\pip-install-dgy9025w\numpy_2d8430dde7ef49e8aae9b794b2ceeb4d C:\Users\mpass\AppData\Local\Temp\pip-install-dgy9025w\numpy_2d8430dde7ef49e8aae9b794b2ceeb4d\.mesonpy-b1anytiy -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=C:\Users\mpass\AppData\Local\Temp\pip-install-dgy9025w\numpy_2d8430dde7ef49e8aae9b794b2ceeb4d\.mesonpy-b1anytiy\meson-python-native-file.ini
#       The Meson build system
#       Version: 1.2.99
#       Source dir: C:\Users\mpass\AppData\Local\Temp\pip-install-dgy9025w\numpy_2d8430dde7ef49e8aae9b794b2ceeb4d
#       Build dir: C:\Users\mpass\AppData\Local\Temp\pip-install-dgy9025w\numpy_2d8430dde7ef49e8aae9b794b2ceeb4d\.mesonpy-b1anytiy
#       Build type: native build
#       Project name: NumPy
#       Project version: 1.26.4
#       WARNING: Failed to activate VS environment: Could not find C:\Program Files (x86)\Microsoft Visual Studio\Installer\vswhere.exe
#
#       ..\meson.build:1:0: ERROR: Unknown compiler(s): [['icl'], ['cl'], ['cc'], ['gcc'], ['clang'], ['clang-cl'], ['pgcc']]
#       The following exception(s) were encountered:
#       Running `icl ""` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#       Running `cl /?` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#       Running `cc --version` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#       Running `gcc --version` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#       Running `clang --version` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#       Running `clang-cl /?` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#       Running `pgcc --version` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#
#       A full log can be found at C:\Users\mpass\AppData\Local\Temp\pip-install-dgy9025w\numpy_2d8430dde7ef49e8aae9b794b2ceeb4d\.mesonpy-b1anytiy\meson-logs\meson-log.txt
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 24.2 -> 24.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Collecting youtube_transcript_api==0.6.2
#   Downloading youtube_transcript_api-0.6.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: requests in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from youtube_transcript_api==0.6.2) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from requests->youtube_transcript_api==0.6.2) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from requests->youtube_transcript_api==0.6.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from requests->youtube_transcript_api==0.6.2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mpass\appdata\local\programs\python\python313\lib\site-packages (from requests->youtube_transcript_api==0.6.2) (2024.8.30)
# Downloading youtube_transcript_api-0.6.2-py3-none-any.whl (24 kB)
# Installing collected packages: youtube_transcript_api
# Successfully installed youtube_transcript_api-0.6.2
# [notice] A new release of pip is available: 24.2 -> 24.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting pypdf==5.0.1
#   Downloading pypdf-5.0.1-py3-none-any.whl.metadata (7.4 kB)
# Downloading pypdf-5.0.1-py3-none-any.whl (294 kB)
# Installing collected packages: pypdf
# Successfully installed pypdf-5.0.1
# [notice] A new release of pip is available: 24.2 -> 24.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Aula 10: Finalizando o projeto

# %% [markdown]
# E agora é só chutar para o gol!
#
# **Comece copiando o código desenvolvido na aula 9!**

# %%
from dotenv import load_dotenv, find_dotenv
from langchain_groq import ChatGroq
from langchain.prompts import ChatPromptTemplate
from langchain_community.document_loaders import WebBaseLoader, YoutubeLoader, PyPDFLoader

_ = load_dotenv(find_dotenv())

chat = ChatGroq(model='llama-3.1-70b-versatile')

def resposta_bot(mensagens, documento):
    system_message = 'Você é um modelo amigável chamado Asimo. Você utiliza as seguintes informações para formular as suas respostas: {informacoes}'
    mensagens_modelo = [('system', system_message)]
    mensagens_modelo += mensagens
    template = ChatPromptTemplate.from_messages(mensagens_modelo)
    chain = template | chat
    return chain.invoke({'informacoes': documento}).content





def carrega_site():
    url_site = input('Digite a URL do site: ')
    loader = WebBaseLoader(url_site) # O loader do LangChain sempre retorna uma lista
    lista_documentos = loader.load()
    documento = ''
    for doc in lista_documentos:
        documento += doc.page_content
    return documento

def carrega_PDF():
    caminho = 'arquivos/2024-07-15_Discussion_Paper_Hamburg_DPA_KI_Models.pdf'
    loader = PyPDFLoader(caminho)
    lista_documentos = loader.load()
    documento = ''
    for doc in lista_documentos:
        documento += doc.page_content
    return documento

def carrega_YT():
    url_site = input('Digite a URL do vídeo do YouTube: ')
    loader = YoutubeLoader.from_youtube_url(url_site, language=['pt'])
    lista_documentos = loader.load()
    documento = ''
    for doc in lista_documentos:
        documento += doc.page_content
    return documento

print('Bem-vindo ao ChatBot da Asimo! (Digite x se você quiser sair!)\n')

texto_selecao = '''
Digite 1 se você quiser conversar com um site
Digite 2 se você quiser conversar com um PDF
Digite 3 se você quiser conversar com um vídeo do YouTube
'''

while True:
  selecao = input(texto_selecao)
  if selecao == '1':
    documento = carrega_site()
    break
  if selecao == '2':
    documento = carrega_PDF()
    break
  if selecao == '3':
    documento = carrega_YT()
    break
  print('Digite apenas um valor entre 1 e 3!')



mensagens = []
while True:
  pergunta = input('Usuário: ')
  if pergunta.lower() == 'x':
    break
  mensagens.append(('user', pergunta))
  resposta = resposta_bot(mensagens, documento)
  mensagens.append(('assistant', resposta))
  print(f'Bot: {resposta}')

print('\nMuito obrigado por utilizar o AsimoBot!')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 from dotenv import load_dotenv, find_dotenv
#       2 from langchain_groq import ChatGroq
# ----> 3 from langchain.prompts import ChatPromptTemplate
#       4 from langchain_community.document_loaders import WebBaseLoader, YoutubeLoader, PyPDFLoader
#       6 _ = load_dotenv(find_dotenv())
#
# ModuleNotFoundError: No module named 'langchain'
