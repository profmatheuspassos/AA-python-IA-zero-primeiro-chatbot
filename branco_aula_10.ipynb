# %%
# !pip install langchain==0.3.0
# !pip install langchain-groq==0.2.0
# !pip install langchain-community==0.3.0
# !pip install youtube_transcript_api==0.6.2
# !pip install pypdf==5.0.1

# %% [markdown]
# # Aula 10: Finalizando o projeto

# %% [markdown]
# E agora é só chutar para o gol!
#
# **Comece copiando o código desenvolvido na aula 9!**

# %%
from dotenv import load_dotenv, find_dotenv
from langchain_groq import ChatGroq
from langchain.prompts import ChatPromptTemplate
from langchain_community.document_loaders import WebBaseLoader, YoutubeLoader, PyPDFLoader

_ = load_dotenv(find_dotenv())

chat = ChatGroq(model='llama-3.1-70b-versatile')

def resposta_bot(mensagens, documento):
    system_message = 'Você é um modelo amigável chamado Asimo. Você utiliza as seguintes informações para formular as suas respostas: {informacoes}'
    mensagens_modelo = [('system', system_message)]
    mensagens_modelo += mensagens
    template = ChatPromptTemplate.from_messages(mensagens_modelo)
    chain = template | chat
    return chain.invoke({'informacoes': documento}).content





def carrega_site():
    url_site = input('Digite a URL do site: ')
    loader = WebBaseLoader(url_site) # O loader do LangChain sempre retorna uma lista
    lista_documentos = loader.load()
    documento = ''
    for doc in lista_documentos:
        documento += doc.page_content
    return documento

def carrega_PDF():
    caminho = 'arquivos/2024-07-15_Discussion_Paper_Hamburg_DPA_KI_Models.pdf'
    loader = PyPDFLoader(caminho)
    lista_documentos = loader.load()
    documento = ''
    for doc in lista_documentos:
        documento += doc.page_content
    return documento

def carrega_YT():
    url_site = input('Digite a URL do vídeo do YouTube: ')
    loader = YoutubeLoader.from_youtube_url(url_site, language=['pt'])
    lista_documentos = loader.load()
    documento = ''
    for doc in lista_documentos:
        documento += doc.page_content
    return documento

print('Bem-vindo ao ChatBot da Asimo! (Digite x se você quiser sair!)\n')

texto_selecao = '''
Digite 1 se você quiser conversar com um site
Digite 2 se você quiser conversar com um PDF
Digite 3 se você quiser conversar com um vídeo do YouTube
'''

while True:
  selecao = input(texto_selecao)
  if selecao == '1':
    documento = carrega_site()
    break
  if selecao == '2':
    documento = carrega_PDF()
    break
  if selecao == '3':
    documento = carrega_YT()
    break
  print('Digite apenas um valor entre 1 e 3!')



mensagens = []
while True:
  pergunta = input('Usuário: ')
  if pergunta.lower() == 'x':
    break
  mensagens.append(('user', pergunta))
  resposta = resposta_bot(mensagens, documento)
  mensagens.append(('assistant', resposta))
  print(f'Bot: {resposta}')

print('\nMuito obrigado por utilizar o AsimoBot!')
# Out:
# Bem-vindo ao ChatBot da Asimo! (Digite x se você quiser sair!)
#
# Bot: Os pontos principais do texto são:
#
# 1. O CEO da empresa de mobilidade Bolt, Markus Villig, considera o trabalho remoto "insanidade" e quer que os funcionários voltem a trabalhar presencialmente no escritório.
#
# 2. Villig acredita que os funcionários que trabalham de locais como Bali estão "desconectados" e que a empresa foi muito "complacente" ao permitir que os funcionários trabalhem de forma remota.
#
# 3. A empresa está planejando implementar uma política de trabalho híbrido a partir de janeiro de 2024, que exigirá que os funcionários trabalhem no escritório pelo menos 12 dias por mês.
#
# 4. A decisão da Bolt não é única, pois outras empresas, como a Amazon, também estão reavaliando suas políticas de trabalho remoto.
#
# 5. A mudança pode levar a resistência ou até mesmo rebelião entre os funcionários, o que pode afetar a produtividade e os resultados financeiros da empresa.
# Bot: Os pontos principais do texto são:
#
# 1. O CEO da Bolt considera o trabalho remoto "insanidade" e quer que os funcionários voltem a trabalhar presencialmente no escritório.
# 2. A empresa está planejando implementar uma política de trabalho híbrido a partir de janeiro de 2024.
# 3. A política exigirá que os funcionários trabalhem no escritório pelo menos 12 dias por mês.
# 4. A Bolt acredita que o trabalho remoto está afetando a produtividade e a conexão entre os funcionários.
# 5. A decisão da Bolt é parte de uma tendência de empresas que estão reavaliando suas políticas de trabalho remoto.
# Bot: De acordo com o texto, há uma possibilidade de resistência ou rebelião entre os funcionários da Bolt em resposta à nova política de trabalho híbrido. Isso pode acontecer porque alguns funcionários podem ter se adaptado ao trabalho remoto e não quererem perder a flexibilidade que isso oferece.
#
# A possibilidade de rebelião é mencionada no texto como uma consequência potencial da mudança na política de trabalho, e é sugerido que isso pode afetar a produtividade e os resultados financeiros da empresa se for amplamente adotado pelos funcionários.
#
# No entanto, é importante notar que a perspectiva de rebelião não é explicitamente detalhada no texto, e não há informações adicionais sobre como a empresa planeja lidar com essa possibilidade.
# Bot: Sim, há uma tendência de empresas reavaliarem suas políticas de trabalho remoto e considerarem a implementação de modelos de trabalho híbridos. Isso é motivado por várias razões, incluindo:
#
# 1. Melhoria da produtividade: Algumas empresas acreditam que o trabalho presencial pode aumentar a produtividade e a colaboração entre os funcionários.
# 2. Cultura corporativa: A presença física no escritório pode ajudar a fortalecer a cultura corporativa e a identidade da empresa.
# 3. Comunicação e colaboração: O trabalho híbrido pode facilitar a comunicação e a colaboração entre os funcionários, especialmente em equipes que precisam trabalhar juntas.
# 4. Retenção de talentos: Algumas empresas podem acreditar que o trabalho híbrido é mais atraente para os funcionários do que o trabalho remoto completo, o que pode ajudar a reter talentos.
#
# No entanto, é importante notar que essa tendência não é universal e que muitas empresas continuam a oferecer opções de trabalho remoto ou flexível para seus funcionários.
#
# Algumas empresas que estão reavaliando suas políticas de trabalho remoto incluem:
#
# * Amazon: A empresa está implementando um modelo de trabalho híbrido que exige que os funcionários trabalhem no escritório pelo menos três dias por semana.
# * Microsoft: A empresa está oferecendo opções de trabalho híbrido para seus funcionários, permitindo que eles escolham quando e como trabalham.
# * Google: A empresa está implementando um modelo de trabalho híbrido que exige que os funcionários trabalhem no escritório pelo menos três dias por semana.
#
# É importante notar que cada empresa tem suas próprias necessidades e prioridades, e a decisão de implementar um modelo de trabalho híbrido depende de muitos fatores, incluindo a natureza do trabalho, a cultura corporativa e as necessidades dos funcionários.
#
# Muito obrigado por utilizar o AsimoBot!
